# %% [markdown]
# Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# Answer:-
#
# Flask is built on top of WSGI (which is a standard for Python web apps) and uses Jinja2 for templating, allowing you to create dynamic HTML pages. It’s a popular choice for developers who want to get something up and running quickly, whether it’s a small app or a RESTful API.
#
# Advantages of Flask Framework
#
# 1.Lightweight and Simple:
#
# Flask is easy to get started with. It has a minimal setup, so you can focus on building your application without getting bogged down by unnecessary features.
#
# 2.Flexibility:
#
# You have the freedom to structure your app however you like. Want to use a specific database or library? Go for it! Flask doesn’t force you into a particular way of doing things.
#
# 3.Easy to Learn:
#
# If you’re new to web development, Flask is a great choice. Its straightforward syntax and clear documentation make it accessible for beginners.
#
# 4.Built-in Development Server:
#
# Flask comes with a handy development server, so you can test your app locally without needing to set up anything complicated.
#
# 5.Extensible:
#
# You can easily add features to your Flask app using extensions. There are tons of third-party libraries available for things like user authentication, database management, and more.
#
# 6.Great for APIs:
#
# Flask is particularly good for building RESTful APIs. It makes it easy to handle different types of requests and responses.
#
# 7.Jinja2 Templating:
#
# With Jinja2, you can create dynamic web pages that can display data from your application. It’s powerful and flexible, making it easy to design your front end.
#
# 8.Strong Community:
#
# Flask has a large community of developers, which means you can find plenty of tutorials, forums, and resources to help you out if you get stuck.
#
# 9.Perfect for Prototyping:
#
# If you have an idea you want to test out quickly, Flask is ideal. You can whip up a prototype in no time and iterate on it as you go.
#
# In Summary
#
# Flask is a fantastic choice for anyone looking to build web applications with Python. Its lightweight nature, flexibility, and ease of use make it a favorite among developers, whether they’re just starting out or are seasoned pros. If you’re thinking about diving into web development, Flask is definitely worth considering!

# %% [markdown]
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.

# %% [markdown]
# Answer:-
#
# Step 1: Installing dependency Flask

# %%
# %pip install Flask

# %% [markdown]
# Step 2: Writing "Hello World" in Flask

# %%
# Importing flask module
from flask import Flask

# Creating flask app object
app = Flask(__name__)

# Creating routing decorator for homepage
@app.route("/")
def hello_world():
    # This function prints Hello world inside Flask app center aligned
    return "<h1 align='center'>Hello, World!</h1>"

# Running the app
if __name__=="__main__":
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.28.0.12:5000
# INFO:werkzeug:Press CTRL+C to quit

# %% [markdown]
# Screenshot of Hello World Center Aligned on Local Web app - http:/127.0.0.1:5000
#
# ![Screenshot 2024-12-17 094337.png](data:image/png;base64,...)

# %% [markdown]
# Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# Answer:-
#
# In Flask, app routing refers to the process of mapping URLs (Uniform Resource Locators) to specific functions or views in your web application. It allows you to define different routes or endpoints that correspond to different pages or functionalities in your application.
#
# When a user makes a request to a specific URL, Flask uses the defined routes to determine which function should handle that request and generate the appropriate response. These routes are defined using the @app.route decorator in Flask.
#
# App routes are used for several reasons:
#
# 1.URL routing: Routes help define the structure of your web application by mapping URLs to specific views or functions. They provide a way to organize and handle different requests to different endpoints.
#
# 2.Page navigation: By defining routes, you can create a navigation system within your application. Users can navigate between different pages or sections by accessing the corresponding URLs.
#
# 3.RESTful APIs: Routes are crucial when building RESTful APIs (Application Programming Interfaces). Each route can represent a specific resource or action, allowing clients to interact with your application through different
# URLs and HTTP methods.
#
# 4.Dynamic routes: Flask allows you to define dynamic routes that can accept variables as part of the URL. This enables you to create flexible and parameterized routes.

# %% [markdown]
# Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
#
# Company Name: ABC Corporation
#
# Location: India
#
# Contact Detail: 999-999-9999
#
# Attach the screenshot of the output in Jupyter Notebook.

# %% [markdown]
# Answer:-

# %%
# Importing flask module
from flask import Flask

# Creating flask app object
app = Flask(__name__)

# Creating a route decorator to show welcome message
@app.route("/welcome")
def welcome_msg():
    # This function shows welcome message h1 center aligned
    return "<h1 align='center'>Welcome to ABC Corporation</h1>"

# Creating route decorator for showing company details
@app.route("/")
def home_page():
    # This function prints company details
    return '''
    <h1>Company Name: ABC Corporation</h1>
    <p>Location: India</p>
    <p>Contact Detail: 999-999-9999</p>
    '''

# Running the app
if __name__=="__main__":
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.28.0.12:5000
# INFO:werkzeug:Press CTRL+C to quit

# %% [markdown]
# 1.Screenshot of homepage or "/" route
#
# ![Screenshot 2024-12-17 094737.png](data:image/png;base64,...)

# %% [markdown]
# 2.Screenshot of "/welcome" route
#
# ![Screenshot 2024-12-17 094927.png](data:image/png;base64,...)

# %% [markdown]
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
# url_for() function.

# %% [markdown]
# Answer:-
#
# In Flask, the url_for() function is used for URL building. This function generates a URL for a given endpoint and can also be used to pass dynamic parameters to the endpoint.

# %% [markdown]
# ![Screenshot 2024-12-17 103639.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-12-17 103745.png](data:image/png;base64,...)
